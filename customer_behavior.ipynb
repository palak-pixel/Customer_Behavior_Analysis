# %%
import pandas as pd
df = pd.read_csv('customer_shopping_behavior.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('customer_shopping_behavior.csv')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'customer_shopping_behavior.csv'

# %%
import os

os.listdir()
# Out:
# ['-1.14-windows.xml',
#  '.anaconda',
#  '.android',
#  '.antigravity',
#  '.conda',
#  '.continuum',
#  '.copilot',
#  '.gemini',
#  '.gnutls',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.MemuHyperv',
#  '.python_history',
#  '.vscode',
#  '.vscode-shared',
#  'anaconda3',
#  'anaconda_projects',
#  'AppData',
#  'Application Data',
#  'c tutorial course',
#  'Contacts',
#  'Cookies',
#  'CrossDevice',
#  'Customer_Shopping_Behavior_Analysis.ipynb',
#  'Customer_Shopping_Behaviour_Analysis.ipynb',
#  'demo',
#  'Documents',
#  'Downloads',
#  'env1',
#  'Favorites',
#  'Links',
#  'Local Settings',
#  'Microsoft',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{c8f929cf-dfb1-11ef-96b9-c04c51c05ad3}.TM.blf',
#  'NTUSER.DAT{c8f929cf-dfb1-11ef-96b9-c04c51c05ad3}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{c8f929cf-dfb1-11ef-96b9-c04c51c05ad3}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'Order Data',
#  'Other Data.xlsx',
#  'package-lock.json',
#  'Pictures',
#  'PrintHood',
#  'Recent',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'Start Menu',
#  'steam',
#  'Templates',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Videos']

# %%
import os

os.listdir('Downloads')
# Out:
# ['class 10th_merged.pdf',
#  'class 10th_merged_compressed.pdf',
#  'DApalak (1).pdf',
#  'DApalak (2).pdf',
#  'Parth_arora_resume.pdf',
#  'Scholarship June 2026 Batch 2023-2027.pdf',
#  'Seminar-Form (1).pdf',
#  'Seminar-Form.pdf',
#  'SEpalak.pdf',
#  'WebPowerBi_PalakArora.pdf']

# %%
import os

for root, dirs, files in os.walk(os.path.expanduser('~')):
    for file in files:
        if file.lower().endswith('.csv'):
            print(os.path.join(root, file))
# Out:
# C:\Users\apala\.vscode\extensions\zobo.php-intellisense-1.3.3\vendor\microsoft\tolerant-php-parser\php-langspec\tools\xreference\section_map.csv
# C:\Users\apala\anaconda3\Lib\site-packages\astropy\coordinates\tests\accuracy\data\fk4_no_e_fk4.csv
# C:\Users\apala\anaconda3\Lib\site-packages\astropy\coordinates\tests\accuracy\data\fk4_no_e_fk5.csv
# C:\Users\apala\anaconda3\Lib\site-packages\astropy\coordinates\tests\accuracy\data\galactic_fk4.csv
# C:\Users\apala\anaconda3\Lib\site-packages\astropy\coordinates\tests\accuracy\data\icrs_fk5.csv
# C:\Users\apala\anaconda3\Lib\site-packages\astropy\io\ascii\tests\data\simple_csv.csv
# C:\Users\apala\anaconda3\Lib\site-packages\astropy\io\ascii\tests\data\simple_csv_missing.csv
# C:\Users\apala\anaconda3\Lib\site-packages\astropy\timeseries\tests\data\binned.csv
# C:\Users\apala\anaconda3\Lib\site-packages\astropy\timeseries\tests\data\sampled.csv
# C:\Users\apala\anaconda3\Lib\site-packages\datashader\examples\data\.data_stubs\nyc_taxi.csv
# C:\Users\apala\anaconda3\Lib\site-packages\holoviews\examples\assets\emoji_embeddings.csv
# C:\Users\apala\anaconda3\Lib\site-packages\holoviews\examples\assets\energy.csv
# C:\Users\apala\anaconda3\Lib\site-packages\holoviews\examples\assets\fb_edges.csv
# C:\Users\apala\anaconda3\Lib\site-packages\holoviews\examples\assets\fb_nodes.csv
# C:\Users\apala\anaconda3\Lib\site-packages\holoviews\examples\assets\station_info.csv
# C:\Users\apala\anaconda3\Lib\site-packages\hvplot\data\crime.csv
# C:\Users\apala\anaconda3\Lib\site-packages\matplotlib\mpl-data\sample_data\data_x_x2_x3.csv
# C:\Users\apala\anaconda3\Lib\site-packages\matplotlib\mpl-data\sample_data\msft.csv
# C:\Users\apala\anaconda3\Lib\site-packages\matplotlib\mpl-data\sample_data\Stocks.csv
# C:\Users\apala\anaconda3\Lib\site-packages\numpy\random\tests\data\mt19937-testset-1.csv
# C:\Users\apala\anaconda3\Lib\site-packages\numpy\random\tests\data\mt19937-testset-2.csv
# C:\Users\apala\anaconda3\Lib\site-packages\numpy\random\tests\data\pcg64-testset-1.csv
# C:\Users\apala\anaconda3\Lib\site-packages\numpy\random\tests\data\pcg64-testset-2.csv
# C:\Users\apala\anaconda3\Lib\site-packages\numpy\random\tests\data\pcg64dxsm-testset-1.csv
# C:\Users\apala\anaconda3\Lib\site-packages\numpy\random\tests\data\pcg64dxsm-testset-2.csv
# C:\Users\apala\anaconda3\Lib\site-packages\numpy\random\tests\data\philox-testset-1.csv
# C:\Users\apala\anaconda3\Lib\site-packages\numpy\random\tests\data\philox-testset-2.csv
# C:\Users\apala\anaconda3\Lib\site-packages\numpy\random\tests\data\sfc64-testset-1.csv
# C:\Users\apala\anaconda3\Lib\site-packages\numpy\random\tests\data\sfc64-testset-2.csv
# C:\Users\apala\anaconda3\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-arccos.csv
# C:\Users\apala\anaconda3\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-arccosh.csv
# C:\Users\apala\anaconda3\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-arcsin.csv
# C:\Users\apala\anaconda3\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-arcsinh.csv
# C:\Users\apala\anaconda3\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-arctan.csv
# C:\Users\apala\anaconda3\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-arctanh.csv
# C:\Users\apala\anaconda3\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-cbrt.csv
# C:\Users\apala\anaconda3\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-cos.csv
# C:\Users\apala\anaconda3\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-cosh.csv
# C:\Users\apala\anaconda3\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-exp.csv
# C:\Users\apala\anaconda3\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-exp2.csv
# C:\Users\apala\anaconda3\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-expm1.csv
# C:\Users\apala\anaconda3\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-log.csv
# C:\Users\apala\anaconda3\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-log10.csv
# C:\Users\apala\anaconda3\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-log1p.csv
# C:\Users\apala\anaconda3\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-log2.csv
# C:\Users\apala\anaconda3\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-sin.csv
# C:\Users\apala\anaconda3\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-sinh.csv
# C:\Users\apala\anaconda3\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-tan.csv
# C:\Users\apala\anaconda3\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-tanh.csv
# C:\Users\apala\anaconda3\Lib\site-packages\sklearn\datasets\data\breast_cancer.csv
# C:\Users\apala\anaconda3\Lib\site-packages\sklearn\datasets\data\iris.csv
# C:\Users\apala\anaconda3\Lib\site-packages\sklearn\datasets\data\linnerud_exercise.csv
# C:\Users\apala\anaconda3\Lib\site-packages\sklearn\datasets\data\linnerud_physiological.csv
# C:\Users\apala\anaconda3\Lib\site-packages\sklearn\datasets\data\wine_data.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\datasets\anes96\anes96.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\datasets\cancer\cancer.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\datasets\ccard\ccard.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\datasets\china_smoking\china_smoking.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\datasets\co2\co2.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\datasets\committee\committee.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\datasets\copper\copper.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\datasets\cpunish\cpunish.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\datasets\danish_data\data.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\datasets\elec_equip\elec_equip.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\datasets\elnino\elnino.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\datasets\engel\engel.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\datasets\fair\fair.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\datasets\fair\fair_pt.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\datasets\fertility\fertility.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\datasets\grunfeld\grunfeld.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\datasets\heart\heart.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\datasets\interest_inflation\E6.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\datasets\interest_inflation\E6_jmulti.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\datasets\longley\longley.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\datasets\macrodata\macrodata.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\datasets\modechoice\modechoice.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\datasets\nile\nile.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\datasets\randhie\randhie.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\datasets\scotland\scotvote.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\datasets\spector\spector.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\datasets\stackloss\stackloss.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\datasets\star98\star98.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\datasets\statecrime\statecrime.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\datasets\strikes\strikes.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\datasets\sunspots\sunspots.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\discrete\tests\results\mnlogit_resid.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\discrete\tests\results\nbinom_resids.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\discrete\tests\results\phat_mnlogit.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\discrete\tests\results\poisson_resid.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\discrete\tests\results\predict_prob_poisson.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\discrete\tests\results\ships.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\discrete\tests\results\sm3533.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\discrete\tests\results\yhat_mnlogit.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\discrete\tests\results\yhat_poisson.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\duration\tests\results\bmt.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\duration\tests\results\bmt_results.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\duration\tests\results\survival_data_1000_10.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\duration\tests\results\survival_data_100_5.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\duration\tests\results\survival_data_20_1.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\duration\tests\results\survival_data_50_1.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\duration\tests\results\survival_data_50_2.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\gam\tests\results\autos.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\gam\tests\results\autos_exog.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\gam\tests\results\autos_predict.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\gam\tests\results\cubic_cyclic_splines_from_mgcv.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\gam\tests\results\gam_PIRLS_results.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\gam\tests\results\logit_gam_mgcv.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\gam\tests\results\motorcycle.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\gam\tests\results\prediction_from_mgcv.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\genmod\tests\results\enet_binomial.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\genmod\tests\results\enet_poisson.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\genmod\tests\results\epil.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\genmod\tests\results\gee_linear_1.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\genmod\tests\results\gee_logistic_1.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\genmod\tests\results\gee_nested_linear_1.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\genmod\tests\results\gee_nominal_1.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\genmod\tests\results\gee_ordinal_1.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\genmod\tests\results\gee_poisson_1.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\genmod\tests\results\igaussident_resids.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\genmod\tests\results\inv_gaussian.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\genmod\tests\results\iris.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\genmod\tests\results\medparlogresids.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\genmod\tests\results\results_tweedie_aweights_nonrobust.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\genmod\tests\results\stata_cancer_glm.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\genmod\tests\results\stata_lbw_glm.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\genmod\tests\results\stata_medpar1_glm.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\miscmodels\tests\results\ologit_ucla.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\multivariate\tests\results\factors_stata.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\multivariate\tests\results\factor_data.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\nonparametric\tests\results\results_kcde.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\nonparametric\tests\results\results_kde.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\nonparametric\tests\results\results_kde_fft.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\nonparametric\tests\results\results_kde_univ_weights.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\nonparametric\tests\results\results_kde_weights.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\nonparametric\tests\results\results_kernel_regression.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\nonparametric\tests\results\test_lowess_delta.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\nonparametric\tests\results\test_lowess_frac.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\nonparametric\tests\results\test_lowess_iter.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\nonparametric\tests\results\test_lowess_simple.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\othermod\tests\results\foodexpenditure.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\othermod\tests\results\methylation-test.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\othermod\tests\results\resid_methylation.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\regression\tests\results\dietox.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\regression\tests\results\lasso_data.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\regression\tests\results\lme00.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\regression\tests\results\lme01.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\regression\tests\results\lme02.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\regression\tests\results\lme03.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\regression\tests\results\lme04.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\regression\tests\results\lme05.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\regression\tests\results\lme06.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\regression\tests\results\lme07.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\regression\tests\results\lme08.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\regression\tests\results\lme09.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\regression\tests\results\lme10.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\regression\tests\results\lme11.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\regression\tests\results\pastes.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\regression\tests\results\results_rls_R.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\regression\tests\results\results_rls_stata.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\regression\tests\results\theil_textile_predict.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\sandbox\regression\tests\racd10data_with_transformed.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\stats\tests\results\binary_constrict.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\stats\tests\results\bootleg.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\stats\tests\results\contingency_table_r_results.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\stats\tests\results\framing.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\stats\tests\results\influence_measures_bool_R.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\stats\tests\results\influence_measures_R.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\stats\tests\results\results_influence_logit.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\stats\tests\results\wspec1.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\stats\tests\results\wspec2.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\stats\tests\results\wspec3.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\stats\tests\results\wspec4.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\treatment\tests\results\cataneo2.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\holtwinters\tests\results\housing-data.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\regime_switching\tests\results\mar_filardo.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\regime_switching\tests\results\results_predict_fedfunds.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\regime_switching\tests\results\results_predict_rgnp.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\cfa_tvpvar_beta.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\cfa_tvpvar_invP.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\cfa_tvpvar_Omega_11.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\cfa_tvpvar_Omega_22.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\cfa_tvpvar_posterior_mean.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\cfa_tvpvar_S10.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\cfa_tvpvar_Si0.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\cfa_tvpvar_state_variates.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\cfa_tvpvar_v10.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\cfa_tvpvar_vi0.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\clark1989.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\exponential_smoothing_params.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\exponential_smoothing_predict.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\exponential_smoothing_states.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\results_clark1989_R.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\results_dynamic_factor_stata.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\results_exact_initial_common_level_R.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\results_exact_initial_common_level_restricted_R.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\results_exact_initial_dfm_R.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\results_exact_initial_local_level_R.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\results_exact_initial_local_linear_trend_missing_R.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\results_exact_initial_local_linear_trend_R.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\results_exact_initial_var1_measurement_error_R.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\results_exact_initial_var1_missing_R.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\results_exact_initial_var1_mixed_R.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\results_exact_initial_var1_R.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\results_intercepts_R.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\results_realgdpar_stata.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\results_sarimax_coverage.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\results_simulation_smoothing0.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\results_simulation_smoothing1.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\results_simulation_smoothing2.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\results_simulation_smoothing3.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\results_simulation_smoothing3_variates.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\results_simulation_smoothing4.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\results_simulation_smoothing5.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\results_simulation_smoothing6.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\results_smoothing2_R.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\results_smoothing3_R.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\results_smoothing_generalobscov_R.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\results_smoothing_R.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\results_varmax_stata.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\results_var_R_output.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\results_var_stata.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\results_wpi1_ar3_matlab_ssm.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\results_wpi1_ar3_stata.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\results_wpi1_missing_ar3_matlab_ssm.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\frbny_nowcast\Nowcasting\data\US\2016-06-29.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\tests\results\frbny_nowcast\Nowcasting\data\US\2016-07-29.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\stl\tests\results\mstl_elec_vic.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\stl\tests\results\mstl_test_results.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\stl\tests\results\stl_co2.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\stl\tests\results\stl_test_results.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\tests\results\arima111_forecasts.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\tests\results\arima212_forecast.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\tests\results\ARMLEConstantPredict.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\tests\results\AROLSConstantPredict.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\tests\results\AROLSNoConstantPredict.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\tests\results\bds_data.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\tests\results\bds_results.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\tests\results\gnpdef.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\tests\results\rand10000.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\tests\results\resids_css_c.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\tests\results\resids_css_nc.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\tests\results\resids_exact_c.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\tests\results\resids_exact_nc.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\tests\results\results_arima_exog_forecasts_css.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\tests\results\results_arima_exog_forecasts_mle.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\tests\results\results_arima_forecasts.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\tests\results\results_arima_forecasts_all_css.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\tests\results\results_arima_forecasts_all_css_diff.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\tests\results\results_arima_forecasts_all_mle.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\tests\results\results_arima_forecasts_all_mle_diff.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\tests\results\results_arma_forecasts.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\tests\results\results_ar_forecast_mle_dynamic.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\tests\results\results_ccf.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\tests\results\results_corrgram.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\tests\results\rgnp.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\tests\results\rgnpq.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\tests\results\stkprc.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\tests\results\yhat_css_c.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\tests\results\yhat_css_nc.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\tests\results\yhat_exact_c.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\tests\results\yhat_exact_nc.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\tests\results\y_arma_data.csv
# C:\Users\apala\anaconda3\Lib\site-packages\statsmodels\tsa\vector_ar\tests\Matlab_results\test_coint.csv
# C:\Users\apala\anaconda3\Lib\site-packages\tornado\test\csv_translations\fr_FR.csv
# C:\Users\apala\anaconda3\pkgs\aext-project-filebrowser-server-4.20.0-py313haa95532_0\info\test\backend_lib\project_filebrowser\tests\test_assets\user_home\test.csv
# C:\Users\apala\anaconda3\pkgs\aext-project-filebrowser-server-4.20.0-py313haa95532_0\info\test\backend_lib\project_filebrowser\tests\test_assets\user_home\test_folder\test2.csv
# C:\Users\apala\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\random\tests\data\mt19937-testset-1.csv
# C:\Users\apala\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\random\tests\data\mt19937-testset-2.csv
# C:\Users\apala\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\random\tests\data\pcg64-testset-1.csv
# C:\Users\apala\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\random\tests\data\pcg64-testset-2.csv
# C:\Users\apala\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\random\tests\data\pcg64dxsm-testset-1.csv
# C:\Users\apala\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\random\tests\data\pcg64dxsm-testset-2.csv
# C:\Users\apala\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\random\tests\data\philox-testset-1.csv
# C:\Users\apala\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\random\tests\data\philox-testset-2.csv
# C:\Users\apala\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\random\tests\data\sfc64-testset-1.csv
# C:\Users\apala\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\random\tests\data\sfc64-testset-2.csv
# C:\Users\apala\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\_core\tests\data\umath-validation-set-arccos.csv
# C:\Users\apala\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\_core\tests\data\umath-validation-set-arccosh.csv
# C:\Users\apala\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\_core\tests\data\umath-validation-set-arcsin.csv
# C:\Users\apala\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\_core\tests\data\umath-validation-set-arcsinh.csv
# C:\Users\apala\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\_core\tests\data\umath-validation-set-arctan.csv
# C:\Users\apala\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\_core\tests\data\umath-validation-set-arctanh.csv
# C:\Users\apala\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\_core\tests\data\umath-validation-set-cbrt.csv
# C:\Users\apala\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\_core\tests\data\umath-validation-set-cos.csv
# C:\Users\apala\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\_core\tests\data\umath-validation-set-cosh.csv
# C:\Users\apala\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\_core\tests\data\umath-validation-set-exp.csv
# C:\Users\apala\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\_core\tests\data\umath-validation-set-exp2.csv
# C:\Users\apala\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\_core\tests\data\umath-validation-set-expm1.csv
# C:\Users\apala\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\_core\tests\data\umath-validation-set-log.csv
# C:\Users\apala\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\_core\tests\data\umath-validation-set-log10.csv
# C:\Users\apala\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\_core\tests\data\umath-validation-set-log1p.csv
# C:\Users\apala\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\_core\tests\data\umath-validation-set-log2.csv
# C:\Users\apala\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\_core\tests\data\umath-validation-set-sin.csv
# C:\Users\apala\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\_core\tests\data\umath-validation-set-sinh.csv
# C:\Users\apala\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\_core\tests\data\umath-validation-set-tan.csv
# C:\Users\apala\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\_core\tests\data\umath-validation-set-tanh.csv
# C:\Users\apala\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\tornado\test\csv_translations\fr_FR.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\random\tests\data\mt19937-testset-1.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\random\tests\data\mt19937-testset-2.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\random\tests\data\pcg64-testset-1.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\random\tests\data\pcg64-testset-2.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\random\tests\data\pcg64dxsm-testset-1.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\random\tests\data\pcg64dxsm-testset-2.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\random\tests\data\philox-testset-1.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\random\tests\data\philox-testset-2.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\random\tests\data\sfc64-testset-1.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\random\tests\data\sfc64-testset-2.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-arccos.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-arccosh.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-arcsin.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-arcsinh.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-arctan.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-arctanh.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-cbrt.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-cos.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-cosh.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-exp.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-exp2.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-expm1.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-log.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-log10.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-log1p.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-log2.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-sin.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-sinh.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-tan.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-tanh.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\random\tests\data\mt19937-testset-1.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\random\tests\data\mt19937-testset-2.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\random\tests\data\pcg64-testset-1.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\random\tests\data\pcg64-testset-2.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\random\tests\data\pcg64dxsm-testset-1.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\random\tests\data\pcg64dxsm-testset-2.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\random\tests\data\philox-testset-1.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\random\tests\data\philox-testset-2.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\random\tests\data\sfc64-testset-1.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\random\tests\data\sfc64-testset-2.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-arccos.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-arccosh.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-arcsin.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-arcsinh.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-arctan.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-arctanh.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-cbrt.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-cos.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-cosh.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-exp.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-exp2.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-expm1.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-log.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-log10.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-log1p.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-log2.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-sin.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-sinh.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-tan.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-tanh.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python312\Lib\site-packages\tornado\test\csv_translations\fr_FR.csv
# C:\Users\apala\AppData\Local\Programs\Python\Python313\Lib\site-packages\tornado\test\csv_translations\fr_FR.csv
# C:\Users\apala\AppData\Local\Temp\2a73d87e-c366-4490-a3e7-38f2b2492319_archive.zip.319\train.csv
# C:\Users\apala\CrossDevice\Pixel 6a\storage\Android\media\com.whatsapp\WhatsApp\Media\WhatsApp Documents\sample_submission.csv
# C:\Users\apala\CrossDevice\Pixel 6a\storage\Android\media\com.whatsapp\WhatsApp\Media\WhatsApp Documents\winequality-red.csv
# C:\Users\apala\CrossDevice\Pixel 6a\storage\Android\media\com.whatsapp\WhatsApp\Media\WhatsApp Documents\XP Points.csv
# C:\Users\apala\OneDrive\Desktop\powerBi\classic_models_dataset\customers.csv
# C:\Users\apala\OneDrive\Desktop\powerBi\classic_models_dataset\employees.csv
# C:\Users\apala\OneDrive\Desktop\powerBi\classic_models_dataset\offices.csv
# C:\Users\apala\OneDrive\Desktop\powerBi\classic_models_dataset\order details.csv
# C:\Users\apala\OneDrive\Desktop\powerBi\classic_models_dataset\orders.csv
# C:\Users\apala\OneDrive\Desktop\powerBi\classic_models_dataset\payments.csv
# C:\Users\apala\OneDrive\Desktop\powerBi\classic_models_dataset\productlines.csv
# C:\Users\apala\OneDrive\Desktop\powerBi\classic_models_dataset\products.csv
# C:\Users\apala\OneDrive\Documents\Power BI Desktop\classic_models_dataset\customers.csv
# C:\Users\apala\OneDrive\Documents\Power BI Desktop\classic_models_dataset\employees.csv
# C:\Users\apala\OneDrive\Documents\Power BI Desktop\classic_models_dataset\offices.csv
# C:\Users\apala\OneDrive\Documents\Power BI Desktop\classic_models_dataset\order details.csv
# C:\Users\apala\OneDrive\Documents\Power BI Desktop\classic_models_dataset\orders.csv
# C:\Users\apala\OneDrive\Documents\Power BI Desktop\classic_models_dataset\payments.csv
# C:\Users\apala\OneDrive\Documents\Power BI Desktop\classic_models_dataset\productlines.csv
# C:\Users\apala\OneDrive\Documents\Power BI Desktop\classic_models_dataset\products.csv

# %%
import os

print(os.path.abspath("Downloads"))
# Out:
# C:\Users\apala\Downloads

# %%
print(os.listdir("Downloads"))
# Out:
# ['class 10th_merged.pdf', 'class 10th_merged_compressed.pdf', 'DApalak (1).pdf', 'DApalak (2).pdf', 'Parth_arora_resume.pdf', 'Scholarship June 2026 Batch 2023-2027.pdf', 'Seminar-Form (1).pdf', 'Seminar-Form.pdf', 'SEpalak.pdf', 'WebPowerBi_PalakArora.pdf']

# %%
import tkinter as tk
from tkinter import filedialog

root = tk.Tk()
root.withdraw()

file_path = filedialog.askopenfilename(
    title="Select customer_shopping_behavior.csv",
    filetypes=[("CSV files", "*.csv")]
)

print(file_path)
# Out:
# D:/download/customer_shopping_behavior (1).csv

# %%
import pandas as pd

df = pd.read_csv(file_path)

df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
#    Shipping Type Discount Applied Promo Code Used  Previous Purchases  \
# 0        Express              Yes             Yes                  14
# 1        Express              Yes             Yes                   2
# 2  Free Shipping              Yes             Yes                  23
# 3   Next Day Air              Yes             Yes                  49
# 4  Free Shipping              Yes             Yes                  31
#
#   Payment Method Frequency of Purchases
# 0          Venmo            Fortnightly
# 1           Cash            Fortnightly
# 2    Credit Card                 Weekly
# 3         PayPal                 Weekly
# 4         PayPal               Annually

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3863 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
#  14  Promo Code Used         3900 non-null   object
#  15  Previous Purchases      3900 non-null   int64
#  16  Payment Method          3900 non-null   object
#  17  Frequency of Purchases  3900 non-null   object
# dtypes: float64(1), int64(4), object(13)
# memory usage: 548.6+ KB

# %%
df.describe(include='all')
# Out:
#         Customer ID          Age Gender Item Purchased  Category  \
# count   3900.000000  3900.000000   3900           3900      3900
# unique          NaN          NaN      2             25         4
# top             NaN          NaN   Male         Blouse  Clothing
# freq            NaN          NaN   2652            171      1737
# mean    1950.500000    44.068462    NaN            NaN       NaN
# std     1125.977353    15.207589    NaN            NaN       NaN
# min        1.000000    18.000000    NaN            NaN       NaN
# 25%      975.750000    31.000000    NaN            NaN       NaN
# 50%     1950.500000    44.000000    NaN            NaN       NaN
# 75%     2925.250000    57.000000    NaN            NaN       NaN
# max     3900.000000    70.000000    NaN            NaN       NaN
#
#         Purchase Amount (USD) Location  Size  Color  Season  Review Rating  \
# count             3900.000000     3900  3900   3900    3900    3863.000000
# unique                    NaN       50     4     25       4            NaN
# top                       NaN  Montana     M  Olive  Spring            NaN
# freq                      NaN       96  1755    177     999            NaN
# mean                59.764359      NaN   NaN    NaN     NaN       3.750065
# std                 23.685392      NaN   NaN    NaN     NaN       0.716983
# min                 20.000000      NaN   NaN    NaN     NaN       2.500000
# 25%                 39.000000      NaN   NaN    NaN     NaN       3.100000
# 50%                 60.000000      NaN   NaN    NaN     NaN       3.800000
# 75%                 81.000000      NaN   NaN    NaN     NaN       4.400000
# max                100.000000      NaN   NaN    NaN     NaN       5.000000
#
#        Subscription Status  Shipping Type Discount Applied Promo Code Used  \
# count                 3900           3900             3900            3900
# unique                   2              6                2               2
# top                     No  Free Shipping               No              No
# freq                  2847            675             2223            2223
# mean                   NaN            NaN              NaN             NaN
# std                    NaN            NaN              NaN             NaN
# min                    NaN            NaN              NaN             NaN
# 25%                    NaN            NaN              NaN             NaN
# 50%                    NaN            NaN              NaN             NaN
# 75%                    NaN            NaN              NaN             NaN
# max                    NaN            NaN              NaN             NaN
#
#         Previous Purchases Payment Method Frequency of Purchases
# count          3900.000000           3900                   3900
# unique                 NaN              6                      7
# top                    NaN         PayPal         Every 3 Months
# freq                   NaN            677                    584
# mean             25.351538            NaN                    NaN
# std              14.447125            NaN                    NaN
# min               1.000000            NaN                    NaN
# 25%              13.000000            NaN                    NaN
# 50%              25.000000            NaN                    NaN
# 75%              38.000000            NaN                    NaN
# max              50.000000            NaN                    NaN

# %%
df.isnull().sum()
# Out:
# Customer ID                0
# Age                        0
# Gender                     0
# Item Purchased             0
# Category                   0
# Purchase Amount (USD)      0
# Location                   0
# Size                       0
# Color                      0
# Season                     0
# Review Rating             37
# Subscription Status        0
# Shipping Type              0
# Discount Applied           0
# Promo Code Used            0
# Previous Purchases         0
# Payment Method             0
# Frequency of Purchases     0
# dtype: int64

# %%
df['Review Rating'] = df.groupby('Category') ['Review Rating'].transform(lambda x: x.fillna(x.median()))

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ','_')
df = df.rename(columns={'purchase_amount_(usd)':'purchase_amount'})

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='object')

# %%
 # create a new column age_group
labels =['Young Adult','Adult','Middle-aged',' Senior']
df['age_group'] = pd.qcut(df['age'],q=4,labels = labels)

# %%
df[['age','age_group']].head(10)
# Out:
#    age    age_group
# 0   55  Middle-aged
# 1   19  Young Adult
# 2   50  Middle-aged
# 3   21  Young Adult
# 4   45  Middle-aged
# 5   46  Middle-aged
# 6   63       Senior
# 7   27  Young Adult
# 8   26  Young Adult
# 9   57  Middle-aged

# %%
# create column purchase_frequency_days 

frequency_mapping = {
    'Fortnightly' : 14,
    'Weekly' : 7,
    'Monthly' : 30,
    'Quarterly':90,
    'Bi-Weekly':14,
    'Annually':365,
    'Every 3 Months':90
}
df['purchase_frequency_days'] = df['frequency_of_purchases'].map(frequency_mapping)

# %%
df[['purchase_frequency_days','frequency_of_purchases']].head(10)
# Out:
#    purchase_frequency_days frequency_of_purchases
# 0                       14            Fortnightly
# 1                       14            Fortnightly
# 2                        7                 Weekly
# 3                        7                 Weekly
# 4                      365               Annually
# 5                        7                 Weekly
# 6                       90              Quarterly
# 7                        7                 Weekly
# 8                      365               Annually
# 9                       90              Quarterly

# %%
df[['discount_applied','promo_code_used']].head(10)
# Out:
#   discount_applied promo_code_used
# 0              Yes             Yes
# 1              Yes             Yes
# 2              Yes             Yes
# 3              Yes             Yes
# 4              Yes             Yes
# 5              Yes             Yes
# 6              Yes             Yes
# 7              Yes             Yes
# 8              Yes             Yes
# 9              Yes             Yes

# %%
(df['discount_applied'] == df['promo_code_used']).all()
# Out:
# np.True_

# %%
df = df.drop('promo_code_used',axis=1)

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases', 'age_group', 'purchase_frequency_days'],
#       dtype='object')

# %%
pip install psycopg2.binary sqlalchemy
# Out:
# Requirement already satisfied: psycopg2.binary in c:\users\apala\anaconda3\lib\site-packages (2.9.12)
# Requirement already satisfied: sqlalchemy in c:\users\apala\anaconda3\lib\site-packages (2.0.43)
# Requirement already satisfied: greenlet>=1 in c:\users\apala\anaconda3\lib\site-packages (from sqlalchemy) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\apala\anaconda3\lib\site-packages (from sqlalchemy) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus

username = "postgres"
password = "Palak@1"
host = "localhost"
port = "5432"
database = "customer_behavior"

password = quote_plus(password)

engine = create_engine(
    f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}"
)

table_name = "customer"

df.to_sql(table_name, engine, if_exists="replace", index=False)

print(f"Data successfully loaded into table '{table_name}' in database '{database}'.")
# Out:
# Data successfully loaded into table 'customer' in database 'customer_behavior'.
